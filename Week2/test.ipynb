# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread('/Users/min02choi/IdeaProjects/Introduction-To-HCI/Week2/eyesample_stim.jpeg')
fig, ax = plt.subplots()
ax.imshow(img)
# ax.plot(pdata['x'], pdata['y'], color='firebrick')

# %%
print("?색반전인데")
# Out:
# ?색반전인데
